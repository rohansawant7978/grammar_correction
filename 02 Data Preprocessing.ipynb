# %% [markdown]
# ## Import libraries & data

# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import re
from tqdm.auto import tqdm
tqdm.pandas()

# %%
final_df = pd.read_csv('/content/drive/MyDrive/Self Case studies/CS02 Grammar Error Corrector/data/final_df_20211027.csv')

# %%
final_df.sample(5)
# Out:
#                                                   correct                                          incorrect
# 589350  Even with Kokubo , he ca n't win any medals bu...  Even Kokubo , he ca n't win any medals but I w...
# 197627                                    Traveling Alone                                    Traveling Alone
# 237461                                       My Sundays !                                  My every sunday !
# 706167  While we are eating , we can share and discuss...  While we are eating , we can share and discuss...
# 879777                                             AVATAR                                             AVATAR

# %%
final_df.shape
# Out:
# (1037561, 2)

# %% [markdown]
# ### Adding length features

# %%
final_df['correct_char_count'] = final_df['correct'].astype('str').apply(lambda x:len(x))
final_df['incorrect_char_count'] = final_df['incorrect'].astype('str').apply(lambda x:len(x))

# %%
final_df['correct_word_count'] = final_df['correct'].astype('str').apply(lambda x:len(x.split()))
final_df['incorrect_word_count'] = final_df['incorrect'].astype('str').apply(lambda x:len(x.split()))

# %%
final_df.sample(5)
# Out:
#                                                    correct  ... incorrect_word_count
# 309088                                         Huumm . . .  ...                    4
# 42164    I was told that if the humidity is below 80 % ...  ...                   22
# 769239                                        I 'm sorry .  ...                    4
# 1023801                                   Don ` t be shy !  ...                    6
# 309408   While jogging along the Sakawa river path , I ...  ...                   35
#
# [5 rows x 6 columns]

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Removing Missing/NA

# %%
pd.DataFrame(final_df.isna().sum(),columns=['missing_count'])
# Out:
#                       missing_count
# correct                           1
# incorrect                         1
# correct_char_count                0
# incorrect_char_count              0
# correct_word_count                0
# incorrect_word_count              0

# %%
final_df[final_df.isna().any(axis=1)]
# Out:
#        correct incorrect  ...  correct_word_count  incorrect_word_count
# 222211     NaN       NaN  ...                   1                     1
#
# [1 rows x 6 columns]

# %%
final_df = final_df.dropna().reset_index(drop=True)

# %%
final_df.shape
# Out:
# (1037560, 6)

# %%
final_df.sample(5)
# Out:
#                                                    correct  ... incorrect_word_count
# 354851                   It is already time to go to bed .  ...                    9
# 456981                      I had a bad cold for 2 weeks .  ...                    9
# 1037274  It is not unusual to keep ( retain ) the space...  ...                   23
# 120748                        Today , I started lang - 8 .  ...                    8
# 351195                                                 URL  ...                    1
#
# [5 rows x 6 columns]

# %% [markdown]
# ### Keep unique sentence pairs

# %%
print(f"total number of duplicate pairs: {len(final_df[final_df['correct']==final_df['incorrect']])}")
# Out:
# total number of duplicate pairs: 539201

# %%
print(f"total number of duplicate pairs: {len(final_df[final_df['correct']==final_df['incorrect']])}")
# Out:
# total number of duplicate pairs: 539202

# %%
final_df[final_df['correct']==final_df['incorrect']].sample(10)
# Out:
#                                                    correct  ... incorrect_word_count
# 289768                                     I am Japanese .  ...                    4
# 495494             Intransitive verb and transitive verb .  ...                    6
# 552991              Besause there are more and more cars .  ...                    8
# 574158                                           start ! !  ...                    3
# 904143                                      Shooting stars  ...                    2
# 1023994                                  India 's Tigers !  ...                    4
# 17865                  We went Sagano to a bamboo forest .  ...                    8
# 555163                                              Phew !  ...                    2
# 81329    That 's why , I am fall in love with her at fi...  ...                   15
# 199201     I heard there are still earthquakes there . . .  ...                   10
#
# [10 rows x 6 columns]

# %%
final_df = final_df[final_df['correct']!=final_df['incorrect']]

# %%
final_df.shape
# Out:
# (498359, 6)

# %%
final_df.sample(5)
# Out:
#                                                    correct  ... incorrect_word_count
# 216176   We are waiting you guys to help and we hope we...  ...                   13
# 780441                  in order to survive in the world .  ...                    8
# 1027514  I think that is a long time , but I am not goo...  ...                   15
# 484994        Last Monday , a lot of snow fell in Pohang .  ...                   13
# 210825     I 've been learning English for ten years now .  ...                    9
#
# [5 rows x 6 columns]

# %% [markdown]
# ### Remove Duplicates

# %%
print(f'total number of duplicates: {final_df.duplicated().sum()}')
# Out:
# total number of duplicates: 2021

# %%
final_df[final_df.duplicated(keep=False)].sort_values('correct')
# Out:
#                                                    correct  ... incorrect_word_count
# 717379   ( I seriously want to escape , all the way , t...  ...                   19
# 1027462  ( I seriously want to escape , all the way , t...  ...                   19
# 802135                                               : - )  ...                    3
# 800388                                               : - )  ...                    3
# 161743                          A : How much did it cost ?  ...                    8
# ...                                                    ...  ...                  ...
# 350827                               to be continued . . .  ...                    6
# 17343                                to be continued . . .  ...                    6
# 633235                               to be continued . . .  ...                    6
# 767284                               today was a bad day .  ...                    6
# 223150                               today was a bad day .  ...                    6
#
# [3129 rows x 6 columns]

# %%
final_df = final_df.drop_duplicates().reset_index(drop=True)

# %%
final_df.shape
# Out:
# (496338, 6)

# %%
final_df.sample(5)
# Out:
#                                                   correct  ... incorrect_word_count
# 136984  If you click the address above , you can see a...  ...                   21
# 457701  I always share my happiness and sorrow with he...  ...                   17
# 236326  The only thing I could do was just readyour en...  ...                   12
# 441145                  I should be born 10 years later .  ...                    8
# 206214  I will think wrote about out my answers to the...  ...                   18
#
# [5 rows x 6 columns]

# %% [markdown]
# ### Remove Small sentences

# %%
final_df[final_df['incorrect_char_count']<2].shape
# Out:
# (5, 6)

# %%
final_df = final_df[final_df['incorrect_char_count']>2].reset_index(drop=True)

# %%
final_df.shape
# Out:
# (496326, 6)

# %%
final_df[final_df['correct_char_count']<2].shape
# Out:
# (27, 6)

# %%
final_df[final_df['correct_char_count']<2].sample(10)
# Out:
#        correct       incorrect  ...  correct_word_count  incorrect_word_count
# 9786         .    daily life .  ...                   1                     3
# 6073         -             - -  ...                   1                     2
# 287866       .             o .  ...                   1                     2
# 101957       )           lol )  ...                   1                     2
# 113360       .             M .  ...                   1                     2
# 461049       .      had them .  ...                   1                     3
# 439410       .       on face .  ...                   1                     3
# 80604        .  to near park .  ...                   1                     4
# 42876        .      At first .  ...                   1                     3
# 34956        ,   Maiko Nakai ,  ...                   1                     3
#
# [10 rows x 6 columns]

# %%
final_df = final_df[final_df['correct_char_count']>2].reset_index(drop=True)

# %%
final_df.shape
# Out:
# (496287, 6)

# %% [markdown]
# ### Clean text

# %%
#https://www.analyticsvidhya.com/blog/2020/04/beginners-guide-exploratory-data-analysis-text-data/
contractions_dict = { "ain't": "are not","'s":" is","aren't": "are not",
                     "can't": "cannot","can't've": "cannot have",
                     "'cause": "because","could've": "could have","couldn't": "could not",
                     "couldn't've": "could not have", "didn't": "did not","doesn't": "does not",
                     "don't": "do not","hadn't": "had not","hadn't've": "had not have",
                     "hasn't": "has not","haven't": "have not","he'd": "he would",
                     "he'd've": "he would have","he'll": "he will", "he'll've": "he will have",
                     "how'd": "how did","how'd'y": "how do you","how'll": "how will",
                     "I'd": "I would", "I'd've": "I would have","I'll": "I will",
                     "I'll've": "I will have","I'm": "I am","I've": "I have", "isn't": "is not",
                     "it'd": "it would","it'd've": "it would have","it'll": "it will",
                     "it'll've": "it will have", "let's": "let us","ma'am": "madam",
                     "mayn't": "may not","might've": "might have","mightn't": "might not", 
                     "mightn't've": "might not have","must've": "must have","mustn't": "must not",
                     "mustn't've": "must not have", "needn't": "need not",
                     "needn't've": "need not have","o'clock": "of the clock","oughtn't": "ought not",
                     "oughtn't've": "ought not have","shan't": "shall not","sha'n't": "shall not",
                     "shan't've": "shall not have","she'd": "she would","she'd've": "she would have",
                     "she'll": "she will", "she'll've": "she will have","should've": "should have",
                     "shouldn't": "should not", "shouldn't've": "should not have","so've": "so have",
                     "that'd": "that would","that'd've": "that would have", "there'd": "there would",
                     "there'd've": "there would have", "they'd": "they would",
                     "they'd've": "they would have","they'll": "they will",
                     "they'll've": "they will have", "they're": "they are","they've": "they have",
                     "to've": "to have","wasn't": "was not","we'd": "we would",
                     "we'd've": "we would have","we'll": "we will","we'll've": "we will have",
                     "we're": "we are","we've": "we have", "weren't": "were not","what'll": "what will",
                     "what'll've": "what will have","what're": "what are", "what've": "what have",
                     "when've": "when have","where'd": "where did", "where've": "where have",
                     "who'll": "who will","who'll've": "who will have","who've": "who have",
                     "why've": "why have","will've": "will have","won't": "will not",
                     "won't've": "will not have", "would've": "would have","wouldn't": "would not",
                     "wouldn't've": "would not have","y'all": "you all", "y'all'd": "you all would",
                     "y'all'd've": "you all would have","y'all're": "you all are",
                     "y'all've": "you all have", "you'd": "you would","you'd've": "you would have",
                     "you'll": "you will","you'll've": "you will have", "you're": "you are",
                     "you've": "you have","n\'t":" not","\'re":" are","\'s": " is","\'d":" would",
                     "\'ll": " will","\'t":" not","\'ve": " have","\'m":" am"}


# Regular expression for finding contractions
contractions_re=re.compile('(%s)' % '|'.join(contractions_dict.keys()))

# Function for expanding contractions
def expand_contractions(text,contractions_dict=contractions_dict):
    def replace(match):
        return contractions_dict[match.group(0)]
    return contractions_re.sub(replace, text)

# %%
# https://stackoverflow.com/a/47091490/4084039
def clean(text):
    text = re.sub('\s*\<.*?\>\s', '', text)
    text = re.sub('\s*\(.*?\)\s', '', text)
    text = re.sub('\s*\[.*?\]\s', '', text)
    text = re.sub('\s*\{.*?\}\s', '', text)
    text = re.sub("[-+@#^/|*(){}$~<>=_%:;]","",text)
    text = text.replace("\\","")
    text = re.sub("\[","",text)
    text = re.sub("\]","",text)
    text = re.sub("\<","",text)
    text = re.sub("\>","",text)
    text = re.sub("\(","",text)
    text = re.sub("\)","",text)
    text = re.sub("[0-9]","",text)
    text = ' '.join(text.split())
    return text

# %%
final_df['correct'] = final_df['correct'].progress_apply(clean)
final_df['correct'] = final_df['correct'].progress_apply(expand_contractions)
# Out:
#   0%|          | 0/496287 [00:00<?, ?it/s]
#   0%|          | 0/496287 [00:00<?, ?it/s]

# %%
final_df['incorrect'] = final_df['incorrect'].progress_apply(clean)
final_df['incorrect'] = final_df['incorrect'].progress_apply(expand_contractions)
# Out:
#   0%|          | 0/496287 [00:00<?, ?it/s]
#   0%|          | 0/496287 [00:00<?, ?it/s]

# %%
final_df.sample(5)
# Out:
#                                                   correct  ... incorrect_word_count
# 347971                                    I  am curious .  ...                    4
# 299394                   with a light sweep it  is done .  ...                    8
# 449458  After checking the blackboard , I found out th...  ...                   26
# 379481                    I am considering this surgery .  ...                    6
# 82752            She had been trying to apologize all day  ...                    9
#
# [5 rows x 6 columns]

# %%
final_df.isna().sum()
# Out:
# correct                 0
# incorrect               0
# correct_char_count      0
# incorrect_char_count    0
# correct_word_count      0
# incorrect_word_count    0
# dtype: int64

# %%
# final_df.to_csv('/content/drive/MyDrive/Self Case studies/CS02 Grammar Error Corrector/data/final_df_preprocessed_2021111201.csv',index=False)
